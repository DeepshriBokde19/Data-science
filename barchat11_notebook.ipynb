# %% [markdown]
# <a href="https://colab.research.google.com/github/DeepshriBokde19/Data-science/blob/main/barchat11_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
import matplotlib.pyplot as plt
x=["python","c++","c","java"]
y=[80,70,50,90]
plt.xlabel("languages",fontsize=10)
plt.ylabel("no",fontsize=10)
plt.title("Barchart",fontsize=15)
plt.bar(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt

x = ["python", "c++", "c", "java"]
y = [80, 70, 50, 90]
z=[20,30,40,50]
plt.xlabel("Languages", fontsize=10)
plt.ylabel("Number", fontsize=10)
plt.title("Bar Chart", fontsize=15)
plt.bar(x,y,width=0.4,color="r",label="popularity")
plt.bar(x,z,width=0.4,color="y",label="popularity1")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = ["python", "c++", "c", "java"]
y = [80, 70, 50, 90]
z=[20,30,40,50]

p=np.arange(len(x))
width=0.2
p1=[j+width for j in p]

plt.xlabel("Languages", fontsize=10)
plt.ylabel("Number", fontsize=10)
plt.title("Bar Chart", fontsize=15)

plt.bar(p,y,width,color="r",label="popularity")
plt.bar(p1,z,width,color="y",label="popularity1")

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()
